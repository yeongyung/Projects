# %%
import matplotlib.pyplot as plt 
from glob import glob
import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,BatchNormalization

import tensorflow.keras.utils as np_utils
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
#import tensorflow_addons as tfa
from keras.models import Model

from matplotlib.colors import ListedColormap
#from keras.utils.training_utils import multi_gpu_model


from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns
import os
import pandas as pd


import pickle
from joblib import dump, load
# Out:
# 2023-08-07 11:50:36.167464: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-07 11:50:36.209466: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 1.GPU 메모리 자동 증가 설정

# %%
# GPU 메모리 자동 증가 설정
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# # 2.Loading data

# %%
# %%time
grids=500
base='/tf/'
data = np.load(base+str(grids)+'data.npz')
X_train = data['X_train']
y_train = data['y_train']
X_val = data['X_val']
y_val = data['y_val']
X_test = data['X_test']
y_test = data['y_test']
# Out:
# CPU times: user 764 ms, sys: 271 ms, total: 1.04 s
# Wall time: 1.03 s

# %% [markdown]
# # 3.Reshaping & Normalization

# %%
# %%time
#num_pixels = X_train.shape[1] * X_train.shape[2]
print(X_train.shape)
X_train = X_train.reshape((X_train.shape[0],grids,grids,1)).astype('float32')
X_test = X_test.reshape((X_test.shape[0],grids,grids,1)).astype('float32')
X_val = X_val.reshape((X_val.shape[0],grids,grids,1)).astype('float32')
print(X_train.shape)
#Normalization                          
maxvalue=X_train[X_train>0].max()

X_train = X_train / maxvalue
X_train[np.isnan(X_train)==True]=0
X_train[np.isinf(X_train)==True]=0

X_test = X_test / maxvalue
X_test[np.isnan(X_test)==True]=0
X_test[np.isinf(X_test)==True]=0

X_val = X_val / maxvalue
X_val[np.isnan(X_val)==True]=0
X_val[np.isinf(X_val)==True]=0
# Out:
# (252, 500, 500)
# (252, 500, 500, 1)
# CPU times: user 412 ms, sys: 226 ms, total: 638 ms
# Wall time: 632 ms

# %% [markdown]
# # add) Masking SB <26 (brighter) or >=26 (darker)

# %% [markdown]
# X_test[X_test<26]=0

# %% [markdown]
# # 4. one-hot encoding outputs

# %%
# %%time
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
y_val = np_utils.to_categorical(y_val)
num_classes = y_test.shape[1]
# Out:
# CPU times: user 247 µs, sys: 100 µs, total: 347 µs
# Wall time: 271 µs

# %% [markdown]
# # 5. Model building

# %%
strategy = tf.distribute.MirroredStrategy()
Droprate=0.2
def baseline_model():
# create model
    model = Sequential()
    model.add(Conv2D(32, (5, 5), input_shape=(grids,grids, 1),strides=(1, 1), activation='relu',padding='same'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D())
    model.add(Dropout(Droprate))
    
    model.add(Conv2D(64, (3, 3), activation='relu',strides=(1, 1),padding='same'))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D())
    model.add(Dropout(Droprate))
    
    model.add(Flatten())
    model.add(Dense(128,activation='relu'))
    model.add(Dense(num_classes,activation='softmax'))

    #model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])    
    model.compile(loss=tf.keras.losses.CategoricalFocalCrossentropy(), optimizer='adam', metrics=['accuracy'])    
    # Compile model
    return model

# build the model
with strategy.scope():
    model=baseline_model()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# 2023-08-07 11:50:56.903732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46686 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:4b:00.0, compute capability: 8.6
# 2023-08-07 11:50:56.904335: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46686 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:b1:00.0, compute capability: 8.6
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 500, 500, 32)      832
#
#  batch_normalization (Batch  (None, 500, 500, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 250, 250, 32)      0
#  D)
#
#  dropout (Dropout)           (None, 250, 250, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 250, 250, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 250, 250, 64)      256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 125, 125, 64)      0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 125, 125, 64)      0
#
#  flatten (Flatten)           (None, 1000000)           0
#
#  dense (Dense)               (None, 128)               128000128
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 128020227 (488.36 MB)
# Trainable params: 128020035 (488.36 MB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Fitting Model

# %%
#start_time = tf.timestamp()

# Fit the model
history=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, batch_size=32, verbose=2)
# Final evaluation of the model

save_dir = "/tf/Results/models/%i/Log/CNN/"%grids
model_name = '%i_CV2_32_5_64_3_Batch_FL'%(grids)#_Drop_0.2
model_path = os.path.join(save_dir, model_name+'.h5')
model.save(model_path)
print('\n Saved trained model at %s ' % model_path)

scores = model.evaluate(X_test, y_test, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))



# 실행 시간 계산
#end_time = tf.timestamp()
#execution_time = end_time - start_time
#print("Execution time: ", execution_time.numpy(), " seconds")

# history 객체를 저장
dump(history.history, '/tf/Results/histories/%i/Log/CNN/'%grids+model_name+'.joblib')
# Out:
# Epoch 1/20
# INFO:tensorflow:Collective all_reduce tensors: 12 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Collective all_reduce tensors: 12 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2023-08-07 11:51:23.701272: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-08-07 11:51:26.376851: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-08-07 11:51:27.771181: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-08-07 11:51:29.374403: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-07 11:51:31.661501: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fbb4ae4b840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-07 11:51:31.661550: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-08-07 11:51:31.661558: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-08-07 11:51:31.669498: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-07 11:51:31.825567: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 8/8 - 15s - loss: 1.2628 - accuracy: 0.6151 - val_loss: 1.3222 - val_accuracy: 0.6719 - 15s/epoch - 2s/step
# Epoch 2/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 1.3222 - val_accuracy: 0.6719 - 1s/epoch - 167ms/step
# Epoch 3/20
# 8/8 - 1s - loss: 1.3272 - accuracy: 0.6706 - val_loss: 1.3222 - val_accuracy: 0.6719 - 1s/epoch - 169ms/step
# Epoch 4/20
# 8/8 - 1s - loss: 1.3272 - accuracy: 0.6706 - val_loss: 1.3222 - val_accuracy: 0.6719 - 1s/epoch - 170ms/step
# Epoch 5/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 2.4691 - val_accuracy: 0.3281 - 1s/epoch - 169ms/step
# Epoch 6/20
# 8/8 - 1s - loss: 1.3272 - accuracy: 0.6706 - val_loss: 3.7777 - val_accuracy: 0.0625 - 1s/epoch - 166ms/step
# Epoch 7/20
# 8/8 - 1s - loss: 1.3272 - accuracy: 0.6706 - val_loss: 3.7777 - val_accuracy: 0.0625 - 1s/epoch - 169ms/step
# Epoch 8/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 3.7777 - val_accuracy: 0.0625 - 1s/epoch - 184ms/step
# Epoch 9/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 3.7777 - val_accuracy: 0.0625 - 1s/epoch - 172ms/step
# Epoch 10/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 3.7777 - val_accuracy: 0.0625 - 1s/epoch - 168ms/step
# Epoch 11/20
# 8/8 - 1s - loss: 1.3272 - accuracy: 0.6706 - val_loss: 3.7777 - val_accuracy: 0.0625 - 1s/epoch - 165ms/step
# Epoch 12/20
# 8/8 - 1s - loss: 1.3272 - accuracy: 0.6706 - val_loss: 3.7777 - val_accuracy: 0.0625 - 1s/epoch - 172ms/step
# Epoch 13/20
# 8/8 - 1s - loss: 1.3272 - accuracy: 0.6706 - val_loss: 3.7777 - val_accuracy: 0.0625 - 1s/epoch - 178ms/step
# Epoch 14/20
# 8/8 - 1s - loss: 1.3123 - accuracy: 0.6706 - val_loss: 3.7777 - val_accuracy: 0.0625 - 1s/epoch - 170ms/step
# Epoch 15/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 1.7000 - val_accuracy: 0.5781 - 1s/epoch - 163ms/step
# Epoch 16/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 1.4365 - val_accuracy: 0.6406 - 1s/epoch - 172ms/step
# Epoch 17/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 1.3947 - val_accuracy: 0.6406 - 1s/epoch - 172ms/step
# Epoch 18/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 1.5740 - val_accuracy: 0.6094 - 1s/epoch - 182ms/step
# Epoch 19/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 1.7629 - val_accuracy: 0.5625 - 1s/epoch - 168ms/step
# Epoch 20/20
# 8/8 - 1s - loss: 1.3112 - accuracy: 0.6746 - val_loss: 1.7629 - val_accuracy: 0.5625 - 1s/epoch - 167ms/step
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  Saved trained model at /tf/Results/models/500/Log/CNN/500_CV2_32_5_64_3_Batch_FL.h5
# Baseline Error: 52.50%
# ['/tf/Results/histories/500/Log/CNN/500_CV2_32_5_64_3_Batch_FL.joblib']

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 500, 500, 32)      832
#
#  batch_normalization (Batch  (None, 500, 500, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 250, 250, 32)      0
#  D)
#
#  dropout (Dropout)           (None, 250, 250, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 250, 250, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 250, 250, 64)      256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 125, 125, 64)      0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 125, 125, 64)      0
#
#  flatten (Flatten)           (None, 1000000)           0
#
#  dense (Dense)               (None, 128)               128000128
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 128020227 (488.36 MB)
# Trainable params: 128020035 (488.36 MB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Confusion Matrix

# %%
y_pred=model.predict(X_test)
confM=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(y_pred,axis=1))
class_totals = np.sum(confM, axis=1)
cm_norm = confM / class_totals[:, np.newaxis]
np.savez('/tf/Results/confusion/'+str(grids)+'/Log/CNN/'+model_name+'.npz', confusion=confM)
# Out:
# 3/3 [==============================] - 0s 21ms/step

# %%
labels=['MergerX','MergerO','MergerΔ']
#print(data)
# Drawing confusion matrix with seaborn
plt.figure(figsize=(6,5))
sns.heatmap(cm_norm,annot=True,fmt=".1%",cmap='GnBu',xticklabels=labels, yticklabels=labels)
plt.xlabel('predictive value')
plt.ylabel('actual value')

plt.title(model_name)
plt.show()

# %%
report=classification_report(np.argmax(y_test,axis=1),np.argmax(y_pred,axis=1),output_dict=True)

df=pd.DataFrame(report).transpose()
df.to_hdf('/tf/Results/confusion/'+str(grids)+'/Log/CNN/'+model_name+'.h5',key='Galaxy',mode='w')   
df
# Out:
#               precision    recall  f1-score  support
# 0              0.606557  0.685185  0.643478   54.000
# 1              0.000000  0.000000  0.000000   21.000
# 2              0.062500  0.200000  0.095238    5.000
# accuracy       0.475000  0.475000  0.475000    0.475
# macro avg      0.223019  0.295062  0.246239   80.000
# weighted avg   0.413332  0.475000  0.440300   80.000

# %% [markdown]
# # 7. Drawing Filters and Feature maps

# %% [markdown]
# ## 7-1) summary of model

# %%
for i in range(len(model.layers)):
    layer = model.layers[i]
    # check for convolutional layer
    if 'conv' not in layer.name: continue
    # summarize output shape
    #print(i, layer.name, layer.output.shape)
    filters, biases = layer.get_weights()
    print(i,layer.name, filters.shape)
# Out:
# 0 conv2d (5, 5, 1, 32)
# 4 conv2d_1 (3, 3, 32, 64)

# %% [markdown]
# ## 7-2) Drawing trained filters

# %%
# 필터를 이미지로 변환하여 시각화합니다.
filters1, biases1 = model.layers[0].get_weights()
fig=plt.figure(figsize=(12, 12))
print(filters1.shape)
for i in range(filters1.shape[3]):
    ax=plt.subplot(8, 4, i + 1)
    plt.imshow(filters1[:, :, 0, i], cmap='gray')
    plt.axis('off')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.tight_layout()
plt.show()

# %%
filters2, biases2 = model.layers[3].get_weights()
plt.figure(figsize=(15, 5))
for i in range(filters2.shape[3]):
    plt.subplot(8, 8, i + 1)
    plt.imshow(filters2[:, :, 0, i], cmap='gray')
    plt.axis('off')
    
plt.show()
plt.figure(figsize=(15, 5))
for i in range(filters2.shape[3]):
    plt.subplot(8, 8, i + 1)
    plt.imshow(filters2[:, :, 1, i], cmap='gray')
    plt.axis('off')
plt.show()

# %% [markdown]
# ## 7-3) Drawing feature_maps

# %%
outlay=[model.layers[i].output for i in [0,4]]
outputs1=Model(inputs=model.inputs,outputs=outlay)

# %%
test=np.expand_dims(X_test[1], axis=0)
print(y_test[1])
feature_maps=outputs1.predict(test)
# Out:
# [1. 0. 0.]
# 1/1 [==============================] - 0s 188ms/step

# %%
fig=plt.figure(figsize=(16,8))
for i in range(32):
    ax=plt.subplot(4,8,i+1)
    plt.imshow(feature_maps[0][0,:,:,i],cmap='gray')
    plt.axis('off')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.tight_layout()
plt.show()

# %%
fig=plt.figure(figsize=(12,12))
for i in range(64):
    ax=plt.subplot(8,8,i+1)
    plt.imshow(feature_maps[1][0, :, :, i],cmap='gray')
    plt.axis('off')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 8. Drawing Hisotries(loss,accuracy) of the models

# %%
# plotting the metrics
fig = plt.figure(figsize=(10,2.5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
history.history['val_loss']
# Out:
# [1.3221871852874756,
#  1.3221871852874756,
#  1.3221871852874756,
#  1.3221871852874756,
#  2.469132661819458,
#  3.7776777744293213,
#  3.7776777744293213,
#  3.7776777744293213,
#  3.7776777744293213,
#  3.7776777744293213,
#  3.7776777744293213,
#  3.7776777744293213,
#  3.7776777744293213,
#  3.7776777744293213,
#  1.699962854385376,
#  1.436514139175415,
#  1.3946540355682373,
#  1.5740323066711426,
#  1.7629163265228271,
#  1.7629163265228271]
