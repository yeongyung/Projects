# %%
import matplotlib.pyplot as plt 
from glob import glob
import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,BatchNormalization

import tensorflow.keras.utils as np_utils
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
#import tensorflow_addons as tfa
from keras.models import Model

from matplotlib.colors import ListedColormap
import matplotlib as mpl
#from keras.utils.training_utils import multi_gpu_model


from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns
import os
import math
import pandas as pd

# %%
# GPU를 사용하도록 설정
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [raw]
# # GPU 메모리 자동 증가 설정
# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#     for gpu in gpus:
#         tf.config.experimental.set_memory_growth(gpu, True)

# %%
# %%time
grids=500
base='/tf/dataset/'
data = np.load(base+str(grids)+'data_noiseX_nside2.npz')
# Out:
# CPU times: user 4.12 ms, sys: 5 µs, total: 4.12 ms
# Wall time: 2.95 ms

# %%
name_train = data['name_train'].copy()
X_train = data['X_train'].copy()
y_train = data['y_train'].copy().astype(int)
#y_train[y_train==2]=1

name_val = data['name_val'].copy()
X_val = data['X_val'].copy()
y_val = data['y_val'].copy().astype(int)
#y_val[y_val==2]=1

name_test = data['name_test'].copy()
X_test = data['X_test'].copy()
y_test = data['y_test'].copy().astype(int)
#y_test[y_test==2]=1

# %% [markdown]
# ## Randomize Xtrain and Ytrain

# %%
numtrain = X_train.shape[0]
print(numtrain)
# Out:
# 2172

# %%
import random
randidx = list(range(numtrain))
random.shuffle(randidx)

# %%
y_train[randidx]
# Out:
# array([1, 0, 0, ..., 1, 1, 1])

# %%
X_train = X_train[randidx]
y_train = y_train[randidx]

# %% [markdown]
# ## Show Images

# %%
fig=plt.figure(figsize=(14, 24))
for i in range(40):
    ax=plt.subplot(8, 5, i + 1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title('Label: '+str(y_train[i]))
    plt.axis('off')
    #ax.get_xaxis().set_visible(False)
    #ax.get_yaxis().set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Masking and Normalizing Images

# %% [markdown]
# #### Finding `nan` and `inf` pixels

# %%
print([np.count_nonzero(np.isnan(X_train)), np.count_nonzero(np.isinf(X_train))])
# Out:
# [0, 99529430]

# %%
ivalid = ~np.isnan(X_test) & ~np.isinf(X_test)
maxvalue = np.max(X_test[ivalid])
minvalue = np.min(X_test[ivalid])
medvalue = np.median(X_test[ivalid])
lowqvalue = np.percentile(X_test[ivalid],25)
highqvalue = np.percentile(X_test[ivalid],75)
maxvalue = np.ceil(maxvalue)
print([medvalue,lowqvalue,highqvalue,minvalue,maxvalue])
# Out:
# [32.00109373129973, 29.81272271309141, 34.39861269372098, 16.35107886967143, 53.0]

# %%
X_test[X_test > medvalue]= medvalue
X_val[X_val > medvalue]= medvalue
X_train[X_train > medvalue]= medvalue

# %% [markdown]
# ### `masking` < 26

# %%
#X_test[X_test<26.0]=0
#X_val[X_val<26.0]=0
#X_train[X_train<26.0]=0

# %% [raw]
# X_test[np.isinf(X_test)]=maxvalue
# X_val[np.isinf(X_val)]=maxvalue
# X_train[np.isinf(X_train)]=maxvalue

# %% [markdown]
# ### `Reshaping` and `one-hot encoding`

# %%
X_train = X_train.reshape((X_train.shape[0],grids,grids,1)).astype('float32')
X_test = X_test.reshape((X_test.shape[0],grids,grids,1)).astype('float32')
X_val = X_val.reshape((X_val.shape[0],grids,grids,1)).astype('float32')

y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
y_val = np_utils.to_categorical(y_val)
num_classes = y_test.shape[1]

# %% [markdown]
# ## `Normalization`

# %%
maxval = np.max([np.max(X_train[~np.isinf(X_train)]),np.max(X_val[~np.isinf(X_val)]),np.max(X_test[~np.isinf(X_test)])])
minval = np.min([np.min(X_train[~np.isinf(X_train)]),np.min(X_val[~np.isinf(X_val)]),np.min(X_test[~np.isinf(X_test)])])
print(maxval,minval, X_train[~np.isinf(X_train)].max())
# Out:
# 32.001095 16.351078 32.001095

# %% [markdown]
# #### hong dc's method

# %%
X_train = np.abs(1.0 - (X_train - minval) / (maxval - minval))
X_test = np.abs(1.0 - (X_test - minval) / (maxval - minval))
X_val = np.abs(1.0 - (X_val - minval) / (maxval - minval))

# %% [raw]
# ## method of mine

# %% [markdown]
# X_train = X_train / maxval
# X_test = X_test / maxval
# X_val = X_val / maxval

# %% [raw]
# ### changing `inf -> 0`

# %% [raw]
# X_train[np.isinf(X_train)]=0
# X_test[np.isinf(X_test)]=0
# X_val[np.isinf(X_val)]=0

# %% [markdown]
# ### 값이 0 ~ 1 사이로 잘 normalization 되었음을 확인

# %%
print(np.max(X_test),np.min(X_test))
print(np.max(X_train),np.min(X_train))
print(np.max(X_val),np.min(X_val))
# Out:
# 1.0 0.0
# 0.9996372 0.0
# 1.0 0.0

# %%
fig=plt.figure(figsize=(14, 36))
for i in range(60):
    ax=plt.subplot(12, 5, i + 1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title('Label: '+str(y_train[i]))
    plt.axis('off')
    #ax.get_xaxis().set_visible(False)
    #ax.get_yaxis().set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model building

# %%
strategy = tf.distribute.MirroredStrategy()
Droprate=0.2
def baseline_model():
# create model
    model = Sequential()
    model.add(Conv2D(16, (5, 5), input_shape=(grids,grids, 1),strides=(1, 1), activation='relu',padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D())
    model.add(Dropout(Droprate))
    
    model.add(Conv2D(32, (3, 3), activation='relu',strides=(1, 1),padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D())
    model.add(Dropout(Droprate))
    
    model.add(Conv2D(32, (3, 3), activation='relu',strides=(1, 1),padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D())
    model.add(Dropout(Droprate))
    
    model.add(Conv2D(32, (3, 3), activation='relu',strides=(1, 1),padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D())
    model.add(Dropout(Droprate))

    model.add(Flatten())
    model.add(Dense(128,activation='relu'))
    model.add(Dense(num_classes,activation='softmax'))

    model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])    
    return model

# build the model
with strategy.scope():
    model=baseline_model()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2023-10-05 09:10:35.864473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46686 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:4b:00.0, compute capability: 8.6
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).

# %%
history=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200, batch_size=128, verbose=2)
scores = model.evaluate(X_test, y_test, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
# Out:
# Epoch 1/200
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2023-10-05 09:10:45.662990: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-10-05 09:10:47.311657: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 09:10:48.994284: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-05 09:10:49.191198: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x224112c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 09:10:49.191238: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-10-05 09:10:49.198094: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 09:10:49.352743: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 17/17 - 28s - loss: 8.6955 - accuracy: 0.4535 - val_loss: 27.5338 - val_accuracy: 0.3676 - 28s/epoch - 2s/step
# Epoch 2/200
# 17/17 - 6s - loss: 0.9248 - accuracy: 0.5470 - val_loss: 43.5916 - val_accuracy: 0.3676 - 6s/epoch - 364ms/step
# Epoch 3/200
# 17/17 - 6s - loss: 0.8422 - accuracy: 0.5428 - val_loss: 47.2026 - val_accuracy: 0.3676 - 6s/epoch - 336ms/step
# Epoch 4/200
# 17/17 - 6s - loss: 0.7675 - accuracy: 0.6404 - val_loss: 46.8521 - val_accuracy: 0.3676 - 6s/epoch - 332ms/step
# Epoch 5/200
# 17/17 - 6s - loss: 0.6852 - accuracy: 0.7067 - val_loss: 45.2002 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 6/200
# 17/17 - 7s - loss: 0.5977 - accuracy: 0.7564 - val_loss: 42.9732 - val_accuracy: 0.3676 - 7s/epoch - 384ms/step
# Epoch 7/200
# 17/17 - 5s - loss: 0.5493 - accuracy: 0.7790 - val_loss: 39.7281 - val_accuracy: 0.3676 - 5s/epoch - 321ms/step
# Epoch 8/200
# 17/17 - 6s - loss: 0.5003 - accuracy: 0.8020 - val_loss: 35.7304 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 9/200
# 17/17 - 5s - loss: 0.4739 - accuracy: 0.8246 - val_loss: 32.0431 - val_accuracy: 0.3676 - 5s/epoch - 319ms/step
# Epoch 10/200
# 17/17 - 6s - loss: 0.4516 - accuracy: 0.8333 - val_loss: 29.2158 - val_accuracy: 0.3676 - 6s/epoch - 346ms/step
# Epoch 11/200
# 17/17 - 5s - loss: 0.4139 - accuracy: 0.8448 - val_loss: 27.8132 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 12/200
# 17/17 - 6s - loss: 0.3840 - accuracy: 0.8568 - val_loss: 25.8792 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 13/200
# 17/17 - 6s - loss: 0.3789 - accuracy: 0.8550 - val_loss: 25.4985 - val_accuracy: 0.3676 - 6s/epoch - 329ms/step
# Epoch 14/200
# 17/17 - 5s - loss: 0.3538 - accuracy: 0.8651 - val_loss: 25.9109 - val_accuracy: 0.3676 - 5s/epoch - 323ms/step
# Epoch 15/200
# 17/17 - 6s - loss: 0.3295 - accuracy: 0.8757 - val_loss: 26.9825 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 16/200
# 17/17 - 6s - loss: 0.3097 - accuracy: 0.8844 - val_loss: 28.7806 - val_accuracy: 0.3676 - 6s/epoch - 324ms/step
# Epoch 17/200
# 17/17 - 5s - loss: 0.2867 - accuracy: 0.8987 - val_loss: 29.8416 - val_accuracy: 0.3676 - 5s/epoch - 318ms/step
# Epoch 18/200
# 17/17 - 6s - loss: 0.2744 - accuracy: 0.8987 - val_loss: 30.4272 - val_accuracy: 0.3676 - 6s/epoch - 327ms/step
# Epoch 19/200
# 17/17 - 6s - loss: 0.2458 - accuracy: 0.9088 - val_loss: 31.3426 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 20/200
# 17/17 - 5s - loss: 0.2335 - accuracy: 0.9130 - val_loss: 30.8990 - val_accuracy: 0.3676 - 5s/epoch - 319ms/step
# Epoch 21/200
# 17/17 - 6s - loss: 0.2078 - accuracy: 0.9254 - val_loss: 31.0418 - val_accuracy: 0.3676 - 6s/epoch - 326ms/step
# Epoch 22/200
# 17/17 - 6s - loss: 0.2031 - accuracy: 0.9259 - val_loss: 31.9334 - val_accuracy: 0.3676 - 6s/epoch - 332ms/step
# Epoch 23/200
# 17/17 - 5s - loss: 0.1806 - accuracy: 0.9365 - val_loss: 32.9340 - val_accuracy: 0.3676 - 5s/epoch - 323ms/step
# Epoch 24/200
# 17/17 - 6s - loss: 0.1647 - accuracy: 0.9392 - val_loss: 32.7075 - val_accuracy: 0.3676 - 6s/epoch - 324ms/step
# Epoch 25/200
# 17/17 - 6s - loss: 0.1565 - accuracy: 0.9461 - val_loss: 33.2239 - val_accuracy: 0.3676 - 6s/epoch - 324ms/step
# Epoch 26/200
# 17/17 - 6s - loss: 0.1715 - accuracy: 0.9383 - val_loss: 35.0203 - val_accuracy: 0.3676 - 6s/epoch - 344ms/step
# Epoch 27/200
# 17/17 - 7s - loss: 0.1453 - accuracy: 0.9424 - val_loss: 34.3010 - val_accuracy: 0.3676 - 7s/epoch - 391ms/step
# Epoch 28/200
# 17/17 - 6s - loss: 0.1380 - accuracy: 0.9471 - val_loss: 34.5866 - val_accuracy: 0.3676 - 6s/epoch - 340ms/step
# Epoch 29/200
# 17/17 - 6s - loss: 0.1183 - accuracy: 0.9586 - val_loss: 35.6558 - val_accuracy: 0.3676 - 6s/epoch - 326ms/step
# Epoch 30/200
# 17/17 - 6s - loss: 0.1247 - accuracy: 0.9503 - val_loss: 35.6891 - val_accuracy: 0.3676 - 6s/epoch - 330ms/step
# Epoch 31/200
# 17/17 - 6s - loss: 0.1169 - accuracy: 0.9540 - val_loss: 36.7589 - val_accuracy: 0.3676 - 6s/epoch - 358ms/step
# Epoch 32/200
# 17/17 - 6s - loss: 0.0976 - accuracy: 0.9613 - val_loss: 34.9164 - val_accuracy: 0.3676 - 6s/epoch - 348ms/step
# Epoch 33/200
# 17/17 - 5s - loss: 0.0916 - accuracy: 0.9632 - val_loss: 33.1189 - val_accuracy: 0.3676 - 5s/epoch - 319ms/step
# Epoch 34/200
# 17/17 - 5s - loss: 0.0793 - accuracy: 0.9687 - val_loss: 36.4655 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 35/200
# 17/17 - 6s - loss: 0.0712 - accuracy: 0.9724 - val_loss: 35.6438 - val_accuracy: 0.3676 - 6s/epoch - 331ms/step
# Epoch 36/200
# 17/17 - 6s - loss: 0.0691 - accuracy: 0.9728 - val_loss: 36.1681 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 37/200
# 17/17 - 6s - loss: 0.0664 - accuracy: 0.9747 - val_loss: 36.3332 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 38/200
# 17/17 - 6s - loss: 0.0564 - accuracy: 0.9857 - val_loss: 34.9111 - val_accuracy: 0.3676 - 6s/epoch - 336ms/step
# Epoch 39/200
# 17/17 - 6s - loss: 0.0522 - accuracy: 0.9853 - val_loss: 33.3259 - val_accuracy: 0.3676 - 6s/epoch - 364ms/step
# Epoch 40/200
# 17/17 - 6s - loss: 0.0420 - accuracy: 0.9908 - val_loss: 35.2392 - val_accuracy: 0.3676 - 6s/epoch - 353ms/step
# Epoch 41/200
# 17/17 - 5s - loss: 0.0363 - accuracy: 0.9931 - val_loss: 31.3997 - val_accuracy: 0.3676 - 5s/epoch - 322ms/step
# Epoch 42/200
# 17/17 - 5s - loss: 0.0401 - accuracy: 0.9903 - val_loss: 31.2949 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 43/200
# 17/17 - 6s - loss: 0.0366 - accuracy: 0.9926 - val_loss: 32.7703 - val_accuracy: 0.3676 - 6s/epoch - 327ms/step
# Epoch 44/200
# 17/17 - 6s - loss: 0.0302 - accuracy: 0.9959 - val_loss: 30.9507 - val_accuracy: 0.3676 - 6s/epoch - 354ms/step
# Epoch 45/200
# 17/17 - 6s - loss: 0.0234 - accuracy: 0.9968 - val_loss: 32.8532 - val_accuracy: 0.3676 - 6s/epoch - 324ms/step
# Epoch 46/200
# 17/17 - 5s - loss: 0.0252 - accuracy: 0.9949 - val_loss: 30.9844 - val_accuracy: 0.3676 - 5s/epoch - 319ms/step
# Epoch 47/200
# 17/17 - 6s - loss: 0.0188 - accuracy: 0.9972 - val_loss: 31.1080 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 48/200
# 17/17 - 6s - loss: 0.0167 - accuracy: 0.9968 - val_loss: 34.3862 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 49/200
# 17/17 - 6s - loss: 0.0197 - accuracy: 0.9959 - val_loss: 30.6673 - val_accuracy: 0.3676 - 6s/epoch - 333ms/step
# Epoch 50/200
# 17/17 - 6s - loss: 0.0179 - accuracy: 0.9977 - val_loss: 36.6601 - val_accuracy: 0.3676 - 6s/epoch - 330ms/step
# Epoch 51/200
# 17/17 - 6s - loss: 0.0159 - accuracy: 0.9986 - val_loss: 38.4126 - val_accuracy: 0.3676 - 6s/epoch - 334ms/step
# Epoch 52/200
# 17/17 - 6s - loss: 0.0135 - accuracy: 0.9977 - val_loss: 36.9237 - val_accuracy: 0.3676 - 6s/epoch - 326ms/step
# Epoch 53/200
# 17/17 - 5s - loss: 0.0186 - accuracy: 0.9972 - val_loss: 37.0558 - val_accuracy: 0.3676 - 5s/epoch - 322ms/step
# Epoch 54/200
# 17/17 - 6s - loss: 0.0197 - accuracy: 0.9959 - val_loss: 40.2895 - val_accuracy: 0.3676 - 6s/epoch - 346ms/step
# Epoch 55/200
# 17/17 - 6s - loss: 0.0293 - accuracy: 0.9922 - val_loss: 42.0849 - val_accuracy: 0.3676 - 6s/epoch - 355ms/step
# Epoch 56/200
# 17/17 - 6s - loss: 0.0135 - accuracy: 0.9986 - val_loss: 40.3068 - val_accuracy: 0.3676 - 6s/epoch - 327ms/step
# Epoch 57/200
# 17/17 - 6s - loss: 0.0098 - accuracy: 0.9991 - val_loss: 40.7757 - val_accuracy: 0.3676 - 6s/epoch - 331ms/step
# Epoch 58/200
# 17/17 - 5s - loss: 0.0094 - accuracy: 0.9995 - val_loss: 38.7693 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 59/200
# 17/17 - 6s - loss: 0.0091 - accuracy: 0.9991 - val_loss: 41.7620 - val_accuracy: 0.3676 - 6s/epoch - 369ms/step
# Epoch 60/200
# 17/17 - 5s - loss: 0.0115 - accuracy: 0.9982 - val_loss: 36.2743 - val_accuracy: 0.3676 - 5s/epoch - 323ms/step
# Epoch 61/200
# 17/17 - 6s - loss: 0.0099 - accuracy: 0.9995 - val_loss: 37.2762 - val_accuracy: 0.3676 - 6s/epoch - 334ms/step
# Epoch 62/200
# 17/17 - 6s - loss: 0.0086 - accuracy: 0.9986 - val_loss: 44.8627 - val_accuracy: 0.3676 - 6s/epoch - 329ms/step
# Epoch 63/200
# 17/17 - 5s - loss: 0.0425 - accuracy: 0.9857 - val_loss: 36.8732 - val_accuracy: 0.3676 - 5s/epoch - 321ms/step
# Epoch 64/200
# 17/17 - 6s - loss: 0.0403 - accuracy: 0.9862 - val_loss: 29.0607 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 65/200
# 17/17 - 6s - loss: 0.0299 - accuracy: 0.9917 - val_loss: 30.7328 - val_accuracy: 0.3676 - 6s/epoch - 329ms/step
# Epoch 66/200
# 17/17 - 6s - loss: 0.0140 - accuracy: 0.9977 - val_loss: 32.7919 - val_accuracy: 0.3676 - 6s/epoch - 355ms/step
# Epoch 67/200
# 17/17 - 6s - loss: 0.0158 - accuracy: 0.9945 - val_loss: 34.5893 - val_accuracy: 0.3676 - 6s/epoch - 360ms/step
# Epoch 68/200
# 17/17 - 6s - loss: 0.0119 - accuracy: 0.9982 - val_loss: 33.5830 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 69/200
# 17/17 - 6s - loss: 0.0070 - accuracy: 0.9995 - val_loss: 36.6553 - val_accuracy: 0.3676 - 6s/epoch - 327ms/step
# Epoch 70/200
# 17/17 - 6s - loss: 0.0071 - accuracy: 0.9995 - val_loss: 33.9468 - val_accuracy: 0.3676 - 6s/epoch - 339ms/step
# Epoch 71/200
# 17/17 - 6s - loss: 0.0058 - accuracy: 0.9995 - val_loss: 36.0012 - val_accuracy: 0.3676 - 6s/epoch - 377ms/step
# Epoch 72/200
# 17/17 - 6s - loss: 0.0067 - accuracy: 0.9986 - val_loss: 37.9442 - val_accuracy: 0.3676 - 6s/epoch - 339ms/step
# Epoch 73/200
# 17/17 - 5s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 39.8037 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 74/200
# 17/17 - 5s - loss: 0.0057 - accuracy: 0.9995 - val_loss: 38.6718 - val_accuracy: 0.3676 - 5s/epoch - 323ms/step
# Epoch 75/200
# 17/17 - 5s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 41.1404 - val_accuracy: 0.3676 - 5s/epoch - 323ms/step
# Epoch 76/200
# 17/17 - 6s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 40.5280 - val_accuracy: 0.3676 - 6s/epoch - 329ms/step
# Epoch 77/200
# 17/17 - 6s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 39.5277 - val_accuracy: 0.3676 - 6s/epoch - 335ms/step
# Epoch 78/200
# 17/17 - 6s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 40.9359 - val_accuracy: 0.3676 - 6s/epoch - 339ms/step
# Epoch 79/200
# 17/17 - 6s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 40.2078 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 80/200
# 17/17 - 6s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 39.2391 - val_accuracy: 0.3676 - 6s/epoch - 326ms/step
# Epoch 81/200
# 17/17 - 6s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 39.5417 - val_accuracy: 0.3676 - 6s/epoch - 341ms/step
# Epoch 82/200
# 17/17 - 6s - loss: 0.0055 - accuracy: 0.9982 - val_loss: 39.9610 - val_accuracy: 0.3676 - 6s/epoch - 380ms/step
# Epoch 83/200
# 17/17 - 6s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 37.8134 - val_accuracy: 0.3676 - 6s/epoch - 340ms/step
# Epoch 84/200
# 17/17 - 6s - loss: 0.0058 - accuracy: 0.9991 - val_loss: 43.3338 - val_accuracy: 0.3676 - 6s/epoch - 331ms/step
# Epoch 85/200
# 17/17 - 6s - loss: 0.0049 - accuracy: 0.9995 - val_loss: 43.3569 - val_accuracy: 0.3676 - 6s/epoch - 324ms/step
# Epoch 86/200
# 17/17 - 6s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 41.9731 - val_accuracy: 0.3676 - 6s/epoch - 343ms/step
# Epoch 87/200
# 17/17 - 6s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 43.7838 - val_accuracy: 0.3676 - 6s/epoch - 346ms/step
# Epoch 88/200
# 17/17 - 6s - loss: 0.0040 - accuracy: 0.9995 - val_loss: 39.6531 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 89/200
# 17/17 - 6s - loss: 0.0090 - accuracy: 0.9972 - val_loss: 40.3384 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 90/200
# 17/17 - 6s - loss: 0.0148 - accuracy: 0.9959 - val_loss: 50.0913 - val_accuracy: 0.3676 - 6s/epoch - 330ms/step
# Epoch 91/200
# 17/17 - 5s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 53.3625 - val_accuracy: 0.3676 - 5s/epoch - 322ms/step
# Epoch 92/200
# 17/17 - 6s - loss: 0.0110 - accuracy: 0.9982 - val_loss: 45.8550 - val_accuracy: 0.3676 - 6s/epoch - 335ms/step
# Epoch 93/200
# 17/17 - 6s - loss: 0.0156 - accuracy: 0.9959 - val_loss: 39.7823 - val_accuracy: 0.3676 - 6s/epoch - 330ms/step
# Epoch 94/200
# 17/17 - 6s - loss: 0.0149 - accuracy: 0.9968 - val_loss: 47.3651 - val_accuracy: 0.3676 - 6s/epoch - 363ms/step
# Epoch 95/200
# 17/17 - 6s - loss: 0.0114 - accuracy: 0.9982 - val_loss: 15.1010 - val_accuracy: 0.4706 - 6s/epoch - 331ms/step
# Epoch 96/200
# 17/17 - 6s - loss: 0.0090 - accuracy: 0.9982 - val_loss: 30.4880 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 97/200
# 17/17 - 6s - loss: 0.0252 - accuracy: 0.9917 - val_loss: 31.4158 - val_accuracy: 0.3676 - 6s/epoch - 324ms/step
# Epoch 98/200
# 17/17 - 6s - loss: 0.0209 - accuracy: 0.9931 - val_loss: 17.0455 - val_accuracy: 0.4228 - 6s/epoch - 357ms/step
# Epoch 99/200
# 17/17 - 6s - loss: 0.0141 - accuracy: 0.9949 - val_loss: 22.7241 - val_accuracy: 0.3897 - 6s/epoch - 340ms/step
# Epoch 100/200
# 17/17 - 5s - loss: 0.0130 - accuracy: 0.9954 - val_loss: 34.9880 - val_accuracy: 0.3676 - 5s/epoch - 319ms/step
# Epoch 101/200
# 17/17 - 5s - loss: 0.0124 - accuracy: 0.9963 - val_loss: 35.4067 - val_accuracy: 0.3676 - 5s/epoch - 319ms/step
# Epoch 102/200
# 17/17 - 6s - loss: 0.0087 - accuracy: 0.9986 - val_loss: 37.8272 - val_accuracy: 0.3676 - 6s/epoch - 338ms/step
# Epoch 103/200
# 17/17 - 5s - loss: 0.0056 - accuracy: 0.9991 - val_loss: 34.7116 - val_accuracy: 0.3676 - 5s/epoch - 323ms/step
# Epoch 104/200
# 17/17 - 6s - loss: 0.0055 - accuracy: 0.9995 - val_loss: 37.1642 - val_accuracy: 0.3676 - 6s/epoch - 331ms/step
# Epoch 105/200
# 17/17 - 6s - loss: 0.0072 - accuracy: 0.9991 - val_loss: 22.9167 - val_accuracy: 0.3676 - 6s/epoch - 330ms/step
# Epoch 106/200
# 17/17 - 5s - loss: 0.0076 - accuracy: 0.9982 - val_loss: 26.7090 - val_accuracy: 0.3676 - 5s/epoch - 322ms/step
# Epoch 107/200
# 17/17 - 6s - loss: 0.0089 - accuracy: 0.9968 - val_loss: 36.9988 - val_accuracy: 0.3676 - 6s/epoch - 339ms/step
# Epoch 108/200
# 17/17 - 5s - loss: 0.0098 - accuracy: 0.9982 - val_loss: 30.7105 - val_accuracy: 0.3676 - 5s/epoch - 321ms/step
# Epoch 109/200
# 17/17 - 6s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 34.2125 - val_accuracy: 0.3676 - 6s/epoch - 364ms/step
# Epoch 110/200
# 17/17 - 6s - loss: 0.0043 - accuracy: 0.9995 - val_loss: 36.6962 - val_accuracy: 0.3676 - 6s/epoch - 355ms/step
# Epoch 111/200
# 17/17 - 6s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 35.5779 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 112/200
# 17/17 - 6s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 36.7320 - val_accuracy: 0.3676 - 6s/epoch - 326ms/step
# Epoch 113/200
# 17/17 - 5s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 37.1051 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 114/200
# 17/17 - 6s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 37.3886 - val_accuracy: 0.3676 - 6s/epoch - 368ms/step
# Epoch 115/200
# 17/17 - 6s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 38.7511 - val_accuracy: 0.3676 - 6s/epoch - 332ms/step
# Epoch 116/200
# 17/17 - 5s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 38.6380 - val_accuracy: 0.3676 - 5s/epoch - 321ms/step
# Epoch 117/200
# 17/17 - 6s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 37.6714 - val_accuracy: 0.3676 - 6s/epoch - 336ms/step
# Epoch 118/200
# 17/17 - 6s - loss: 0.0028 - accuracy: 0.9995 - val_loss: 38.2934 - val_accuracy: 0.3676 - 6s/epoch - 324ms/step
# Epoch 119/200
# 17/17 - 6s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 41.8205 - val_accuracy: 0.3676 - 6s/epoch - 330ms/step
# Epoch 120/200
# 17/17 - 6s - loss: 0.0030 - accuracy: 0.9995 - val_loss: 38.6837 - val_accuracy: 0.3676 - 6s/epoch - 329ms/step
# Epoch 121/200
# 17/17 - 6s - loss: 0.0031 - accuracy: 0.9995 - val_loss: 37.4841 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 122/200
# 17/17 - 6s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 40.2001 - val_accuracy: 0.3676 - 6s/epoch - 331ms/step
# Epoch 123/200
# 17/17 - 5s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 40.8010 - val_accuracy: 0.3676 - 5s/epoch - 323ms/step
# Epoch 124/200
# 17/17 - 6s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 39.6113 - val_accuracy: 0.3676 - 6s/epoch - 342ms/step
# Epoch 125/200
# 17/17 - 6s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 41.4847 - val_accuracy: 0.3676 - 6s/epoch - 373ms/step
# Epoch 126/200
# 17/17 - 6s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 42.5188 - val_accuracy: 0.3676 - 6s/epoch - 333ms/step
# Epoch 127/200
# 17/17 - 6s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 43.1897 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 128/200
# 17/17 - 6s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 41.5273 - val_accuracy: 0.3676 - 6s/epoch - 342ms/step
# Epoch 129/200
# 17/17 - 6s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 40.9507 - val_accuracy: 0.3676 - 6s/epoch - 344ms/step
# Epoch 130/200
# 17/17 - 6s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 41.0313 - val_accuracy: 0.3676 - 6s/epoch - 339ms/step
# Epoch 131/200
# 17/17 - 6s - loss: 0.0037 - accuracy: 0.9995 - val_loss: 43.8506 - val_accuracy: 0.3676 - 6s/epoch - 329ms/step
# Epoch 132/200
# 17/17 - 6s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 46.0992 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 133/200
# 17/17 - 6s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 43.7570 - val_accuracy: 0.3676 - 6s/epoch - 335ms/step
# Epoch 134/200
# 17/17 - 6s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 44.3899 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 135/200
# 17/17 - 6s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 43.6251 - val_accuracy: 0.3676 - 6s/epoch - 327ms/step
# Epoch 136/200
# 17/17 - 6s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 49.9126 - val_accuracy: 0.3676 - 6s/epoch - 335ms/step
# Epoch 137/200
# 17/17 - 5s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 45.2995 - val_accuracy: 0.3676 - 5s/epoch - 323ms/step
# Epoch 138/200
# 17/17 - 6s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 48.3181 - val_accuracy: 0.3676 - 6s/epoch - 335ms/step
# Epoch 139/200
# 17/17 - 6s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 47.2099 - val_accuracy: 0.3676 - 6s/epoch - 332ms/step
# Epoch 140/200
# 17/17 - 6s - loss: 0.0043 - accuracy: 0.9995 - val_loss: 45.1318 - val_accuracy: 0.3676 - 6s/epoch - 370ms/step
# Epoch 141/200
# 17/17 - 6s - loss: 0.0035 - accuracy: 0.9991 - val_loss: 43.3920 - val_accuracy: 0.3676 - 6s/epoch - 340ms/step
# Epoch 142/200
# 17/17 - 6s - loss: 0.0309 - accuracy: 0.9926 - val_loss: 40.9386 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 143/200
# 17/17 - 5s - loss: 0.0247 - accuracy: 0.9917 - val_loss: 18.6626 - val_accuracy: 0.4430 - 5s/epoch - 321ms/step
# Epoch 144/200
# 17/17 - 6s - loss: 0.2017 - accuracy: 0.9466 - val_loss: 18.4143 - val_accuracy: 0.4522 - 6s/epoch - 331ms/step
# Epoch 145/200
# 17/17 - 6s - loss: 0.3019 - accuracy: 0.9236 - val_loss: 8.6944 - val_accuracy: 0.5809 - 6s/epoch - 352ms/step
# Epoch 146/200
# 17/17 - 6s - loss: 0.1722 - accuracy: 0.9530 - val_loss: 3.4760 - val_accuracy: 0.6949 - 6s/epoch - 328ms/step
# Epoch 147/200
# 17/17 - 5s - loss: 0.0934 - accuracy: 0.9692 - val_loss: 8.1025 - val_accuracy: 0.6305 - 5s/epoch - 323ms/step
# Epoch 148/200
# 17/17 - 6s - loss: 0.0533 - accuracy: 0.9811 - val_loss: 7.2497 - val_accuracy: 0.6048 - 6s/epoch - 333ms/step
# Epoch 149/200
# 17/17 - 6s - loss: 0.0348 - accuracy: 0.9913 - val_loss: 26.7310 - val_accuracy: 0.4099 - 6s/epoch - 341ms/step
# Epoch 150/200
# 17/17 - 6s - loss: 0.0147 - accuracy: 0.9972 - val_loss: 11.8790 - val_accuracy: 0.5460 - 6s/epoch - 339ms/step
# Epoch 151/200
# 17/17 - 6s - loss: 0.0154 - accuracy: 0.9968 - val_loss: 12.1290 - val_accuracy: 0.5662 - 6s/epoch - 331ms/step
# Epoch 152/200
# 17/17 - 6s - loss: 0.0116 - accuracy: 0.9972 - val_loss: 31.4798 - val_accuracy: 0.3842 - 6s/epoch - 358ms/step
# Epoch 153/200
# 17/17 - 6s - loss: 0.0075 - accuracy: 0.9982 - val_loss: 32.4695 - val_accuracy: 0.3768 - 6s/epoch - 333ms/step
# Epoch 154/200
# 17/17 - 5s - loss: 0.0079 - accuracy: 0.9982 - val_loss: 21.3543 - val_accuracy: 0.4136 - 5s/epoch - 322ms/step
# Epoch 155/200
# 17/17 - 5s - loss: 0.0084 - accuracy: 0.9977 - val_loss: 33.1653 - val_accuracy: 0.3695 - 5s/epoch - 323ms/step
# Epoch 156/200
# 17/17 - 6s - loss: 0.0057 - accuracy: 0.9991 - val_loss: 35.6644 - val_accuracy: 0.3658 - 6s/epoch - 338ms/step
# Epoch 157/200
# 17/17 - 6s - loss: 0.0036 - accuracy: 0.9995 - val_loss: 33.0019 - val_accuracy: 0.3676 - 6s/epoch - 339ms/step
# Epoch 158/200
# 17/17 - 6s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 34.7880 - val_accuracy: 0.3658 - 6s/epoch - 332ms/step
# Epoch 159/200
# 17/17 - 6s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 39.6901 - val_accuracy: 0.3676 - 6s/epoch - 331ms/step
# Epoch 160/200
# 17/17 - 6s - loss: 0.0035 - accuracy: 0.9995 - val_loss: 36.6261 - val_accuracy: 0.3676 - 6s/epoch - 340ms/step
# Epoch 161/200
# 17/17 - 6s - loss: 0.0044 - accuracy: 0.9991 - val_loss: 50.7903 - val_accuracy: 0.3676 - 6s/epoch - 326ms/step
# Epoch 162/200
# 17/17 - 6s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 55.5661 - val_accuracy: 0.3676 - 6s/epoch - 329ms/step
# Epoch 163/200
# 17/17 - 5s - loss: 0.0031 - accuracy: 0.9991 - val_loss: 59.6022 - val_accuracy: 0.3676 - 5s/epoch - 322ms/step
# Epoch 164/200
# 17/17 - 6s - loss: 0.0039 - accuracy: 0.9986 - val_loss: 67.4658 - val_accuracy: 0.3676 - 6s/epoch - 332ms/step
# Epoch 165/200
# 17/17 - 6s - loss: 0.0033 - accuracy: 0.9995 - val_loss: 62.9122 - val_accuracy: 0.3676 - 6s/epoch - 327ms/step
# Epoch 166/200
# 17/17 - 6s - loss: 0.0036 - accuracy: 0.9995 - val_loss: 55.3163 - val_accuracy: 0.3676 - 6s/epoch - 331ms/step
# Epoch 167/200
# 17/17 - 6s - loss: 0.0029 - accuracy: 0.9995 - val_loss: 51.7385 - val_accuracy: 0.3676 - 6s/epoch - 367ms/step
# Epoch 168/200
# 17/17 - 6s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 50.9987 - val_accuracy: 0.3676 - 6s/epoch - 380ms/step
# Epoch 169/200
# 17/17 - 6s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 53.2489 - val_accuracy: 0.3676 - 6s/epoch - 333ms/step
# Epoch 170/200
# 17/17 - 6s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 62.8699 - val_accuracy: 0.3676 - 6s/epoch - 327ms/step
# Epoch 171/200
# 17/17 - 6s - loss: 0.0026 - accuracy: 0.9995 - val_loss: 63.9871 - val_accuracy: 0.3676 - 6s/epoch - 335ms/step
# Epoch 172/200
# 17/17 - 6s - loss: 0.0031 - accuracy: 0.9995 - val_loss: 64.1366 - val_accuracy: 0.3676 - 6s/epoch - 359ms/step
# Epoch 173/200
# 17/17 - 6s - loss: 0.0054 - accuracy: 0.9991 - val_loss: 75.2030 - val_accuracy: 0.3676 - 6s/epoch - 337ms/step
# Epoch 174/200
# 17/17 - 6s - loss: 0.0056 - accuracy: 0.9991 - val_loss: 36.2161 - val_accuracy: 0.3676 - 6s/epoch - 324ms/step
# Epoch 175/200
# 17/17 - 6s - loss: 0.0048 - accuracy: 0.9991 - val_loss: 49.0597 - val_accuracy: 0.3676 - 6s/epoch - 327ms/step
# Epoch 176/200
# 17/17 - 6s - loss: 0.0049 - accuracy: 0.9991 - val_loss: 44.5689 - val_accuracy: 0.3676 - 6s/epoch - 337ms/step
# Epoch 177/200
# 17/17 - 5s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 63.2198 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 178/200
# 17/17 - 6s - loss: 0.0038 - accuracy: 0.9991 - val_loss: 57.5995 - val_accuracy: 0.3676 - 6s/epoch - 338ms/step
# Epoch 179/200
# 17/17 - 5s - loss: 0.0036 - accuracy: 0.9991 - val_loss: 61.9821 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 180/200
# 17/17 - 6s - loss: 0.0036 - accuracy: 0.9995 - val_loss: 66.0296 - val_accuracy: 0.3676 - 6s/epoch - 328ms/step
# Epoch 181/200
# 17/17 - 5s - loss: 0.0033 - accuracy: 0.9995 - val_loss: 44.0174 - val_accuracy: 0.3676 - 5s/epoch - 322ms/step
# Epoch 182/200
# 17/17 - 6s - loss: 0.0031 - accuracy: 0.9995 - val_loss: 59.0752 - val_accuracy: 0.3676 - 6s/epoch - 340ms/step
# Epoch 183/200
# 17/17 - 6s - loss: 0.0032 - accuracy: 0.9995 - val_loss: 62.7409 - val_accuracy: 0.3676 - 6s/epoch - 358ms/step
# Epoch 184/200
# 17/17 - 6s - loss: 0.0024 - accuracy: 0.9995 - val_loss: 54.6406 - val_accuracy: 0.3676 - 6s/epoch - 336ms/step
# Epoch 185/200
# 17/17 - 5s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 50.3986 - val_accuracy: 0.3676 - 5s/epoch - 323ms/step
# Epoch 186/200
# 17/17 - 5s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 49.5603 - val_accuracy: 0.3676 - 5s/epoch - 322ms/step
# Epoch 187/200
# 17/17 - 6s - loss: 0.0025 - accuracy: 0.9995 - val_loss: 48.2295 - val_accuracy: 0.3676 - 6s/epoch - 350ms/step
# Epoch 188/200
# 17/17 - 6s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 50.1124 - val_accuracy: 0.3676 - 6s/epoch - 351ms/step
# Epoch 189/200
# 17/17 - 5s - loss: 0.0027 - accuracy: 0.9995 - val_loss: 50.6968 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 190/200
# 17/17 - 5s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 51.2958 - val_accuracy: 0.3676 - 5s/epoch - 321ms/step
# Epoch 191/200
# 17/17 - 5s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 50.0700 - val_accuracy: 0.3676 - 5s/epoch - 321ms/step
# Epoch 192/200
# 17/17 - 6s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 49.5194 - val_accuracy: 0.3676 - 6s/epoch - 331ms/step
# Epoch 193/200
# 17/17 - 6s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 48.6458 - val_accuracy: 0.3676 - 6s/epoch - 335ms/step
# Epoch 194/200
# 17/17 - 6s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 47.8601 - val_accuracy: 0.3676 - 6s/epoch - 325ms/step
# Epoch 195/200
# 17/17 - 6s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 50.1050 - val_accuracy: 0.3676 - 6s/epoch - 326ms/step
# Epoch 196/200
# 17/17 - 5s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 42.9333 - val_accuracy: 0.3676 - 5s/epoch - 320ms/step
# Epoch 197/200
# 17/17 - 6s - loss: 0.0023 - accuracy: 0.9995 - val_loss: 45.5403 - val_accuracy: 0.3676 - 6s/epoch - 332ms/step
# Epoch 198/200
# 17/17 - 6s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 47.2920 - val_accuracy: 0.3676 - 6s/epoch - 361ms/step
# Epoch 199/200
# 17/17 - 6s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 47.9033 - val_accuracy: 0.3676 - 6s/epoch - 365ms/step
# Epoch 200/200
# 17/17 - 6s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 48.7549 - val_accuracy: 0.3676 - 6s/epoch - 324ms/step
# Baseline Error: 63.24%

# %% [markdown]
# # Confusion Matrix

# %%
y_pred=model.predict(X_test)
confM=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(y_pred,axis=1))#normalize=True
#per_confM=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(y_pred,axis=1),normalize='true')
class_totals = np.sum(confM, axis=1)
cm_norm = confM / class_totals[:, np.newaxis]
#np.savez('/tf/Results/confusion/'+str(grids)+'/Log/CNN/'+model_name+'.npz', confusion=confM)
# Out:
# 22/22 [==============================] - 1s 17ms/step

# %%
labels=['MergerX','MergerO','MergerΔ']

# Drawing confusion matrix with seaborn
plt.figure(figsize=(12,5))
ax=plt.subplot(1, 2, 1)
sns.heatmap(confM,annot=True,cmap='GnBu',xticklabels=labels, yticklabels=labels)
plt.xlabel('predictive value')
plt.ylabel('actual value')

ax=plt.subplot(1, 2, 2)
sns.heatmap(cm_norm,annot=True,fmt=".1%",cmap='GnBu',xticklabels=labels, yticklabels=labels)
plt.xlabel('predictive value')

plt.tight_layout()
plt.show()

# %%
report=classification_report(np.argmax(y_test,axis=1),np.argmax(y_pred,axis=1),output_dict=True)
df=pd.DataFrame(report).transpose()
df
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              0.367647  1.000000  0.537634  250.000000
# 1              0.000000  0.000000  0.000000  350.000000
# 2              0.000000  0.000000  0.000000   80.000000
# accuracy       0.367647  0.367647  0.367647    0.367647
# macro avg      0.122549  0.333333  0.179211  680.000000
# weighted avg   0.135164  0.367647  0.197660  680.000000

# %%
# plotting the metrics
fig = plt.figure(figsize=(10,2.5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()
plt.show()
